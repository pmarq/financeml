# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.2f}'.format

# %%
# Especificar o caminho do arquivo CSV
arquivo_csv = r"C:\Users\usuario\Desktop\Programacao\financeml\src\data\dados_tratados\COTAHIST_TODOS_ANOS.csv"

# Ler o arquivo CSV com a codificação apropriada
preco_acoes_todos_os_anos = pd.read_csv(arquivo_csv, encoding='latin1')

# Exibir as primeiras linhas do dataframe lido
pd.DataFrame(preco_acoes_todos_os_anos)
# Out:
#           tipo_registro  data_pregao  cod_bdi cod_negociacao  tipo_mercado  \
# 0                     1     20140102     2.00          ABCB4            10
# 1                     1     20140102    96.00         ABCB4F            20
# 2                     1     20140102    62.00         ABCB4T            30
# 3                     1     20140102     2.00          ABEV3            10
# 4                     1     20140102    96.00         ABEV3F            20
# ...                 ...          ...      ...            ...           ...
# 11587775              1     20240528    82.00       YDUQS207            80
# 11587776              1     20240528    82.00       YDUQS142            80
# 11587777              1     20240528    82.00       YDUQS137            80
# 11587778              1     20240528    82.00       YDUQS132            80
# 11587779              1     20240528    82.00       YDUQS122            80
#
#          noma_empresa especificacao_papel  prazo_dias_merc_termo  \
# 0          ABC BRASIL          PN  EJS N2                    NaN
# 1          ABC BRASIL          PN  EJS N2                    NaN
# 2          ABC BRASIL          PN  EJS N2                 361.00
# 3           AMBEV S/A                  ON                    NaN
# 4           AMBEV S/A                  ON                    NaN
# ...               ...                 ...                    ...
# 11587775        YDUQE          ON      NM                   0.00
# 11587776        YDUQE          ON      NM                   0.00
# 11587777    YDUQE  FM          ON      NM                   0.00
# 11587778    YDUQE  FM          ON      NM                   0.00
# 11587779        YDUQE          ON      NM                   0.00
#
#          moeda_referencia  preco_abertura  ...  numero_negocios  \
# 0                      R$           12.31  ...          1544.00
# 1                      R$           12.10  ...             3.00
# 2                      R$           13.46  ...             2.00
# 3                      R$           17.30  ...         22569.00
# 4                      R$           17.26  ...           341.00
# ...                   ...             ...  ...              ...
# 11587775               R$            7.01  ...             1.00
# 11587776               R$            1.36  ...             5.00
# 11587777               R$            1.09  ...             3.00
# 11587778               R$            0.89  ...             3.00
# 11587779               R$            0.40  ...             3.00
#
#           quantidade_papeis_negociados  volume_total_negociado  \
# 0                            361200.00              4307894.00
# 1                               140.00                 1686.10
# 2                               100.00                 1346.30
# 3                           8035400.00            139744724.00
# 4                             10790.00               187644.20
# ...                                ...                     ...
# 11587775                        900.00                 6309.00
# 11587776                       4000.00                 5697.00
# 11587777                       1900.00                 2201.00
# 11587778                       2200.00                 1972.00
# 11587779                       2200.00                  916.00
#
#           preco_exercicio  ìndicador_correcao_precos  data_vencimento  \
# 0                    0.00                       0.00      99991231.00
# 1                    0.00                       0.00      99991231.00
# 2                    0.00                       0.00      99991231.00
# 3                    0.00                       0.00      99991231.00
# 4                    0.00                       0.00      99991231.00
# ...                   ...                        ...              ...
# 11587775            20.48                       0.00      20240719.00
# 11587776            13.98                       0.00      20240719.00
# 11587777            13.48                       0.00      20240719.00
# 11587778            12.98                       0.00      20240719.00
# 11587779            11.98                       0.00      20240719.00
#
#           fator_cotacao  preco_exercicio_pontos   codigo_isin  \
# 0                  1.00                    0.00  BRABCBACNPR4
# 1                  1.00                    0.00  BRABCBACNPR4
# 2                  1.00                    0.00  BRABCBACNPR4
# 3                  1.00                    0.00  BRABEVACNOR1
# 4                  1.00                    0.00  BRABEVACNOR1
# ...                 ...                     ...           ...
# 11587775           1.00                    0.00  BRYDUQACNOR3
# 11587776           1.00                    0.00  BRYDUQACNOR3
# 11587777           1.00                    0.00  BRYDUQACNOR3
# 11587778           1.00                    0.00  BRYDUQACNOR3
# 11587779           1.00                    0.00  BRYDUQACNOR3
#
#           num_distribuicao_papel
# 0                         121.00
# 1                         121.00
# 2                         121.00
# 3                         100.00
# 4                         100.00
# ...                          ...
# 11587775                  104.00
# 11587776                  104.00
# 11587777                  104.00
# 11587778                  104.00
# 11587779                  104.00
#
# [11587780 rows x 26 columns]

# %%
# Filtrando apenas as colunas desejadas
colunas_desejadas = ['data_pregao', 'cod_negociacao', 'noma_empresa', 'preco_ultimo_negocio']
preco_acoes = preco_acoes_todos_os_anos[colunas_desejadas]

# Filtrando apenas as empresas com cod_negociacao terminando em '3'
preco_acoes = preco_acoes[preco_acoes['cod_negociacao'].str.endswith('3')]

preco_acoes_final3 = preco_acoes 

# Exibindo o DataFrame filtrado
pd.DataFrame(preco_acoes_final3)
# Out:
#           data_pregao cod_negociacao  noma_empresa  preco_ultimo_negocio
# 3            20140102          ABEV3     AMBEV S/A                 17.39
# 8            20140102          AEDU3    ANHANGUERA                 14.55
# 11           20140102          AELP3      AES ELPA                  8.71
# 12           20140102          AGRO3    BRASILAGRO                  9.50
# 13           20140102          ALLL3  ALL AMER LAT                  6.30
# ...               ...            ...           ...                   ...
# 11587615     20240528       VIVAF233          VIVA                  0.23
# 11587616     20240528       VIVTR453         VIVTE                  0.02
# 11587622     20240528       VIVTF483      VIVT  FM                  0.31
# 11587624     20240528       VIVTR463     VIVTE  FM                  0.59
# 11587681     20240528       WEGEH403          WEGE                  0.83
#
# [1067465 rows x 4 columns]

# %%
# Filtrando apenas os códigos de negociação que terminam exatamente com '3'
preco_acoes_final3= preco_acoes_final3[preco_acoes_final3['cod_negociacao'].str.match(r'^[A-Z]{4}3$')]

pd.DataFrame(preco_acoes_final3)
# Out:
#           data_pregao cod_negociacao  noma_empresa  preco_ultimo_negocio
# 3            20140102          ABEV3     AMBEV S/A                 17.39
# 8            20140102          AEDU3    ANHANGUERA                 14.55
# 11           20140102          AELP3      AES ELPA                  8.71
# 12           20140102          AGRO3    BRASILAGRO                  9.50
# 13           20140102          ALLL3  ALL AMER LAT                  6.30
# ...               ...            ...           ...                   ...
# 10751004     20240528          ETER3       ETERNIT                  6.18
# 10751005     20240528          CTNM3     COTEMINAS                  8.25
# 10751007     20240528          CTSA3    SANTANENSE                  2.44
# 10751009     20240528          AMER3    AMERICANAS                  0.53
# 10751011     20240528          NEXP3         NEXPE                  4.13
#
# [599884 rows x 4 columns]

# %%
# Especificar o caminho do arquivo Excel
arquivo_excel = r"C:\Users\usuario\Desktop\Programacao\financeml\src\data\cnpj_acoes_b3.xlsx"

# Ler o arquivo Excel
df_cnpj_acoes_b3 = pd.read_excel(arquivo_excel)

# Exibir as primeiras linhas do dataframe
print(df_cnpj_acoes_b3.head())
# Out:
#   CNPJ das empresas listadas na B3          Unnamed: 1  \
# 0                           Ticker  Denominação social
# 1                            AALR3              Alliar
# 2                            ABCB4          Abc Brasil
# 3                            ABEV3           Ambev S/A
# 4                            AERI3               Aeris
#
#                                           Unnamed: 2      Unnamed: 3
# 0                                     Nome de pregão            CNPJ
# 1                 CENTRO DE IMAGEM DIAGNOSTICOS S.A.  42771949000135
# 2                                BCO ABC BRASIL S.A.  28195667000106
# 3                                         AMBEV S.A.  07526557000100
# 4  AERIS IND. E COM. DE EQUIP. GERACAO DE ENERGIA...  12528708000107

# %%
# Especificar o caminho do arquivo CSV de saída
arquivo_cnpj_acoes_csv = r"C:\Users\usuario\Desktop\Programacao\financeml\src\data\cnpj_acoes_b3.csv"

# Salvar o DataFrame como um arquivo CSV
df_cnpj_acoes_b3.to_csv(arquivo_cnpj_acoes_csv, index=False, encoding='utf-8')

# Ler o arquivo Excel, especificando a segunda linha como cabeçalho (index 1)
df_cnpj_acoes_b3 = pd.read_excel(arquivo_excel, header=1)


# Exibir as primeiras linhas do DataFrame lido do CSV
pd.DataFrame(df_cnpj_acoes_b3)
# Out:
#      Ticker Denominação social  \
# 0     AALR3             Alliar
# 1     ABCB4         Abc Brasil
# 2     ABEV3          Ambev S/A
# 3     AERI3              Aeris
# 4     AESB3         AES Brasil
# ..      ...                ...
# 553   WLMM3        Wlm Ind Com
# 554   WLMM4        Wlm Ind Com
# 555  YBRA3B          Ybyra S/A
# 556   YDUQ3         Yduqs Part
# 557   ZAMP3          ZAMP S.A.
#
#                                         Nome de pregão            CNPJ
# 0                   CENTRO DE IMAGEM DIAGNOSTICOS S.A.  42771949000135
# 1                                  BCO ABC BRASIL S.A.  28195667000106
# 2                                           AMBEV S.A.   7526557000100
# 3    AERIS IND. E COM. DE EQUIP. GERACAO DE ENERGIA...  12528708000107
# 4                              AES BRASIL ENERGIA S.A.  37663076000107
# ..                                                 ...             ...
# 553   WLM PART. E COMÉRCIO DE MÁQUINAS E VEÍCULOS S.A.  33228024000151
# 554   WLM PART. E COMÉRCIO DE MÁQUINAS E VEÍCULOS S.A.  33228024000151
# 555                              YBRA3 TENNOLOGIA LTDA   2217319000107
# 556                           YDUQS PARTICIPACOES S.A.   8807432000110
# 557                                          ZAMP S.A.  13574594000196
#
# [558 rows x 4 columns]

# %%
# Criar o dicionário de mapeamento do Ticker para o CNPJ
ticker_to_cnpj = dict(zip(df_cnpj_acoes_b3['Ticker'], df_cnpj_acoes_b3['CNPJ']))

# Adicionar a coluna CNPJ ao DataFrame preco_acoes_filtrado_final3
preco_acoes_final3['CNPJ'] = preco_acoes_final3['cod_negociacao'].map(ticker_to_cnpj)

# Reorganizar as colunas para colocar a coluna CNPJ antes de cod_negociacao
colunas_ordenadas = ['data_pregao', 'CNPJ', 'cod_negociacao', 'noma_empresa', 'preco_ultimo_negocio']
preco_acoes_final3_cnpj = preco_acoes_final3[colunas_ordenadas]

# Exibir as primeiras linhas do DataFrame atualizado

pd.DataFrame(preco_acoes_final3_cnpj)
# Out:
#          data_pregao              CNPJ cod_negociacao noma_empresa  \
# 1191218   2016-10-28 42771949000135.00          AALR3       ALLIAR
# 1193007   2016-10-31 42771949000135.00          AALR3       ALLIAR
# 1194902   2016-11-01 42771949000135.00          AALR3       ALLIAR
# 1196783   2016-11-03 42771949000135.00          AALR3       ALLIAR
# 1198819   2016-11-04 42771949000135.00          AALR3       ALLIAR
# ...              ...               ...            ...          ...
# 10744183  2024-05-22 13574594000196.00          ZAMP3    ZAMP S.A.
# 10746011  2024-05-23 13574594000196.00          ZAMP3    ZAMP S.A.
# 10747550  2024-05-24 13574594000196.00          ZAMP3    ZAMP S.A.
# 10749144  2024-05-27 13574594000196.00          ZAMP3    ZAMP S.A.
# 10750782  2024-05-28 13574594000196.00          ZAMP3    ZAMP S.A.
#
#           preco_ultimo_negocio
# 1191218                  19.20
# 1193007                  18.06
# 1194902                  17.90
# 1196783                  17.99
# 1198819                  17.75
# ...                        ...
# 10744183                  3.17
# 10746011                  3.07
# 10747550                  2.99
# 10749144                  2.99
# 10750782                  3.02
#
# [599884 rows x 5 columns]

# %%
pasta_salvar = r"C:\Users\usuario\Desktop\Programacao\financeml\src\data\dados_tratados\preco_acoes_final3_cnpj.csv"

# Salvar o dataframe filtrado
preco_acoes_final3_cnpj.to_csv(pasta_salvar, index=False)
